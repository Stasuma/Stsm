# %%
import scipy
from scipy.optimize import linprog
import numpy as np

#ввод размерности матрицы
a=int(input('Видов товаров:'))
b=int(input('Видов материалов:'))

data=[]#ввод значений матрицы
for i in range(b): 
    data.append([])
    for j in range(a):
        data[i].append(float(input('Расход материала на товар: ')))
data1=np.array(data)#делаем матрицу удобнее для восприятия пользователем
data2=data1.transpose()
print('Матрица значений:')
print(data2)

price=[]#ввод цены товаров
for i in range(a):
    price.append(float(input('Цена товара (с минусом):')))
print('Цены товаров')
print(price)

quantity=[]#ввод количества материалов на склад
for i in range(b):
    quantity.append(float(input('Кол-во материала на складе')))
print('Кол-во материалов на складе')
print(quantity)

def function(f):#формируем функцию
    print('Целевая функция в формульном виде')
    func = []
    x = 1
    for i in range(a):
        func1 = [abs(f[i]), '*x', x]
        #к каждому значению строки цены применяем модуль так как они с -
        #и добавляем к нему значение x
        x=x+1
        func.append("".join(map(str,func1)))#убираем кавычки у значений
    print("+".join(map(str,func)))#ставим между значения знак +
function(price)

def value(p, d, q):
    xy=int(input('Решить симплекс-методом (введите 1) или линейного программирования (введите 2)?'))
    if xy==1:
        sm=linprog(p, d, q, method = 'simplex')
        print('Оптимальное значение целевой функции(симплекс):', abs(sm.fun))
        print('При x:',sm.x)
    elif xy==2:
        ov=linprog(p, d, q, method = 'interior-point')
        print('Оптимальное значение целевой функции(лин.прог.):', abs(ov.fun))
        print('При x:',ov.x)
    else:
        print('Введено неверно')
value(price, data, quantity)
# Out:
# Видов товаров:1
# Видов материалов:22
# Расход материала на товар: 345
# Расход материала на товар: 321
# Расход материала на товар: 223
# Расход материала на товар: 345
# Расход материала на товар: 432
# Расход материала на товар: 123
# Расход материала на товар: 543
# Расход материала на товар: 321
# Расход материала на товар: 121
# Расход материала на товар: 1111
# Расход материала на товар: 2345
# Расход материала на товар: 4567
# Расход материала на товар: 543
# Расход материала на товар: 333
# Расход материала на товар: 222
# Расход материала на товар: 11
# Расход материала на товар: 55
# Расход материала на товар: 66
# Расход материала на товар: 77
# Расход материала на товар: 8
# Расход материала на товар: 88
# Расход материала на товар: 99
# Матрица значений:
# [[ 345.  321.  223.  345.  432.  123.  543.  321.  121. 1111. 2345. 4567.
#    543.  333.  222.   11.   55.   66.   77.    8.   88.   99.]]
# Цена товара (с минусом):-3444
# Цены товаров
# [-3444.0]
# Кол-во материала на складе456
# Кол-во материала на складе654
# Кол-во материала на складе444
# Кол-во материала на складе765
# Кол-во материала на складе99
# Кол-во материала на складе88
# Кол-во материала на складе77
# Кол-во материала на складе66
# Кол-во материала на складе55
# Кол-во материала на складе44
# Кол-во материала на складе33
# Кол-во материала на складе22
# Кол-во материала на складе11
# Кол-во материала на складе98
# Кол-во материала на складе87
# Кол-во материала на складе76
# Кол-во материала на складе65
# Кол-во материала на складе54
# Кол-во материала на складе43
# Кол-во материала на складе2
# Кол-во материала на складе21
# Кол-во материала на складе22
# Кол-во материалов на складе
# [456.0, 654.0, 444.0, 765.0, 99.0, 88.0, 77.0, 66.0, 55.0, 44.0, 33.0, 22.0, 11.0, 98.0, 87.0, 76.0, 65.0, 54.0, 43.0, 2.0, 21.0, 22.0]
# Целевая функция в формульном виде
# 3444.0*x1
# Решить симплекс-методом (введите 1) или линейного программирования (введите 2)?1
# Оптимальное значение целевой функции(симплекс): 16.590321874315745
# При x: [0.00481717]

# %%
import matplotlib.pyplot as plt
def graphic():

    plt.show()
graphic()

# %%
import matplotlib.pyplot as plt
def graphic():
    x = [0, abs(vec[0])]
    y = [0, abs(vec[1])]
    plt.plot(x, y)
    plt.show()
    
graphic()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c701a79ffa8b> in <module>
#       6     plt.show()
#       7
# ----> 8 graphic()
#
# <ipython-input-5-c701a79ffa8b> in graphic()
#       1 import matplotlib.pyplot as plt
#       2 def graphic():
# ----> 3     x = [0, abs(vec[0])]
#       4     y = [0, abs(vec[1])]
#       5     plt.plot(x, y)
#
# NameError: name 'vec' is not defined
